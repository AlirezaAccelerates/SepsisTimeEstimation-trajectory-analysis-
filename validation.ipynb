# %%
import pandas as pd
import pickle
import os
# from MODS import sepyIMPORT as si

# %% [markdown]
# ## Analysing encounter pickles

# %%
path = "OUTPUT/encounter_pickles/2014/"
pickles = []
for entry in os.listdir(path):
    if entry.endswith("pickle"):
        pickles.append(entry)

for pkl in pickles:
    pkl_path=os.path.join(path,pkl)
    # print(pkl_path)
    
    with open(pkl_path, 'rb') as pf:
        patients_dict = pickle.load(pf)
        print(patients_dict)
        import sys
        sys.exit()
    # print(patients_dict['sep2_time'].head)
    # print(patients_dict['sofa_scores'].head)
# Out:
# {'csn': 34382978, 'pat_id': 714116, 'cultures_PerCSN':           pat_id proc_code                                proc_desc  \
# csn
# 34382978  714116  H6448131  MRSA Screen for Infection Control (Nose
# 34382978  714116  H6448131  MRSA Screen for Infection Control (Nose
# 34382978  714116  F6193986                      Blood Culture (C&S)
# 34382978  714116  F6193986                      Blood Culture (C&S)
# 34382978  714116  F6193988                      Blood Culture (C&S)
# 34382978  714116  F6193988                      Blood Culture (C&S)
# 34382978  714116  F6188482                      Blood Culture (C&S)
# 34382978  714116  F6188482                      Blood Culture (C&S)
# 34382978  714116  F6188483                      Blood Culture (C&S)
# 34382978  714116  F6188483                      Blood Culture (C&S)
# 34382978  714116  M6482931                     Urine Culture  (C&S)
# 34382978  714116  M6482931                     Urine Culture  (C&S)
# ...
